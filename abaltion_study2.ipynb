# %% [markdown]
# # Ablation study for encoding model

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# using Enzyme dataset

# %% [raw]
# model=["MLPRegressor" , "DecisionTreeRegressor" , "BayesianRidge" , "SGDRegressor"]
# oh_encoding=[0.877 , 0.841 , 0.7937 , 0.85]
# b_encoding=[0.742 , 0.61 , -0.029, -0.99]
# df = pd.DataFrame(list(zip(model, oh_encoding,b_encoding)), columns =['x', 'y',"z"])

# %%
plt.plot(model,  oh_encoding,  color='red',  label='one hot encoding', linewidth=0.8,marker="o")
plt.plot(model,  b_encoding,  color='blue',  label="Binatry encoding",  linewidth=0.8,marker="p")
   
plt.title('')
plt.xlabel('Predictor Models')
plt.ylabel('R2 score')
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 plt.plot(model,  oh_encoding,  color='red',  label='one hot encoding', linewidth=0.8,marker="o")
#       2 plt.plot(model,  b_encoding,  color='blue',  label="Binatry encoding",  linewidth=0.8,marker="p")
#       4 plt.title('')
#
# NameError: name 'model' is not defined

# %%
sns.displot(data=df, kind="ecdf", x="x")

# %% [markdown]
# # Ablation study for random search

# %%
# For ENZYMES DATASET
trainedmodel=[300,480,600,800]

AutoGraph=[70.5,70.80,71.13,71.26]
AutoGraphCRse=[68.10,69.65,70.18,70.85]
AutoGraphCRsa=[69.8,70.2,70.8,70.95]
graphnas =[2000]
graphnas_acc=[0]
graphgym=[1152]
graphgym_acc=[60.8]
pas =[2000]
pas_acc =[0]

plt.plot(trainedmodel,  AutoGraph,  color='blue',  label="P4GNAS",  linewidth=2, markersize=12,marker="p" )
plt.plot(trainedmodel,  AutoGraphCRse,  color='red',  label='P4GNAS_Rse',marker="o",linewidth=2, markersize=12)
plt.plot(trainedmodel,  AutoGraphCRsa,  color='green',  label='P4GNAS_Rsa',marker="v",linewidth=2, markersize=12) 
plt.scatter(graphnas,  graphnas_acc,    label='P4GNAS_Rsa') 
plt.scatter(graphgym,  graphgym_acc,    label='P4GNAS_Rsa') 
plt.scatter(pas,  pas_acc,  label='P4GNAS_Rsa') 


plt.title('')
plt.xlabel('# Trained models')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# For DD DATASET

trainedmodel=[300,480,600,800]

AutoGraph=[78.8,79.86,82.86,82.94]
AutoGraphCRse=[75,78.72,79.83,81.92]
AutoGraphCRsa=[77.6,78.92,81.23,82.14]



plt.plot(trainedmodel,  AutoGraph,  color='blue',  label="P4GNAS",  linewidth=2, markersize=12,marker="p" )
plt.plot(trainedmodel,  AutoGraphCRse,  color='red',  label='P4GNAS_Rse',marker="o",linewidth=2, markersize=12)
plt.plot(trainedmodel,  AutoGraphCRsa,  color='green',  label='P4GNAS_Rsa',marker="v",linewidth=2, markersize=12) 
plt.title('')
plt.xlabel('# Trained models')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# For PROTEINS DATASET
AutoGraph=[76,77.48,77.56,77.98]
AutoGraphCRse=[76.12,77.25,77.27,77.32]
AutoGraphCRsa=[75.88,77.32,77.39,77.54]
trainedmodel=[300,480,600,800]


plt.plot(trainedmodel,  AutoGraph,  color='blue',  label="P4GNAS",  linewidth=2, markersize=12,marker="p" )
plt.plot(trainedmodel,  AutoGraphCRse,  color='red',  label='P4GNAS_Rse',marker="o",linewidth=2, markersize=12)
plt.plot(trainedmodel,  AutoGraphCRsa,  color='green',  label='P4GNAS_Rsa',marker="v",linewidth=2, markersize=12) 
plt.title('')
plt.xlabel('# Trained models')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# For IMDB DATASET
AutoGraph=[69,74.5,75.18,75.97]
AutoGraphCRse=[68.03,74.30,74.49,74.68]
AutoGraphCRsa=[68.29,74.26,74.9,74.86]



plt.plot(trainedmodel,  AutoGraph,  color='blue',  label="P4GNAS",  linewidth=2, markersize=12,marker="p" )
plt.plot(trainedmodel,  AutoGraphCRse,  color='red',  label='P4GNAS_Rse',marker="o",linewidth=2, markersize=12)
plt.plot(trainedmodel,  AutoGraphCRsa,  color='green',  label='P4GNAS_Rsa',marker="v",linewidth=2, markersize=12)    
plt.title('')
plt.xlabel('# Trained models')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# For DD DATASET
trainedmodel=range(75,85)
real=[82.86,82.86,81.83,81.98,80.81,80.69,82.01,80.55,79.8,80.02,81.29,80.77,80.5,80.42,79.87,80.23,80.70
pred=[83.8,83.26,82.59,82.54,82.54,82.16,81.85,81.79,81.68,81.01,81.09,81.0,80.38,80.31,80.5,80.41,80.41,78,80.72,80.51]



plt.plot(trainedmodel,  trainedmodel,  color='red', linewidth=0.5)
plt.scatter(real,  pred,  color='blue',  linewidth=0.8,marker="p")
plt.title('R2 Score=0.54')
plt.xlabel('True Accuracy')
plt.ylabel('Predicted Accuracy')
plt.legend()
plt.grid()
plt.show()
# Out:
#   File "<ipython-input-12-67b616301c90>", line 4
#     pred=[83.8,83.26,82.59,82.54,82.54,82.16,81.85,81.79,81.68,81.01,81.09,81.0,80.38,80.31,80.5,80.41,80.41,78,80.72,80.51]
#     ^
# SyntaxError: invalid syntax

# %%
from sklearn.metrics import r2_score
r2=r2_score(pred,real)
r2
# Out:
# 0.4907788586998064

# %%
# For DD DATASET
trainedmodel=range(70,81)
real=[77.96,76.65,75.53,76.98,77.81,77.69,77.89,76.85,77.33,77.07,77.29,76.45,76.35,75.51,76.17,76.03,76.70
      ,75.33,74.20,74,08]
pred=[79.18,78.58,78.59,78.44,77.90,76.86,77.85,76.79,77.68,77.01,77.09,77.0,76.38,76.31,75.5,75.41,76.41,74.5,74.42,73.9]



plt.plot(trainedmodel,  trainedmodel,  color='red', linewidth=0.5)
plt.scatter(real,  pred,  color='blue',  linewidth=0.8,marker="p")
plt.title('R2 Score=0.54')
plt.xlabel('True Accuracy')
plt.ylabel('Predicted Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# width of the bars
barWidth = 0.3
 
# Choose the height of the blue bars
mlp = [0.83,0.95]
dtr=[0.72,0.71]
sdg=[0.82,0.45]
br=[0.82,0.54]
# Choose the height of the cyan bars
one_hot = [0.95,0.71,0.45,0.54]
yer1 = [0.5, 0.4]
 #["MLPRegressor","DecisionTreeRegressor","SGDRegressor","BayesianRidge"]
# The x position of bars
r1 = np.arange(len(binary))
r2 = [x + barWidth for x in r1]
 
# Create blue bars
plt.bar(r1, mlp, width = barWidth, color = 'blue', edgecolor = 'black', yerr=yer1, capsize=7, label='poacee')
 
# Create cyan bars
plt.bar(r2, dtr, width = barWidth, color = 'cyan', edgecolor = 'black', capsize=7, label='sorgho')
 
# general layout
plt.xticks([r + barWidth for r in range(len(mlp))], ['Binary Encoding', 'One-hot Encoding'])
plt.ylabel('R2 Score')
plt.legend()
 
# Show graphic
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-eb6a5f8ad768> in <module>
#      20
#      21 # Create blue bars
# ---> 22 plt.bar(r1, mlp, width = barWidth, color = 'blue', edgecolor = 'black', yerr=yer1, capsize=7, label='poacee')
#      23
#      24 # Create cyan bars
#
# D:\Anaconda\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# D:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...

# %%
# Encoding regressor ENZYMES
import numpy as np
import matplotlib.pyplot as plt
 
# width of the bars
barWidth = 0.075
 
# Choose the height of the blue bars
mlp = [0.83,0.95]
 
# Choose the height of the cyan bars
dtr = [0.72,0.71]
 
# Choose the height of the error bars (bars1)
yer1 = [0.5, 0.4]
 
sdg=[0.82,0.45]
br=[0.82,0.54]

# Choose the height of the cyan bars
one_hot = [0.95,0.71,0.45,0.54]    
    
# Choose the height of the error bars (bars2)
yer2 = [1, 0.7]
 
# The x position of bars
r1 = np.arange(len(mlp))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
# Create blue bars
plt.bar(r1, mlp, width = barWidth, color = 'goldenrod', edgecolor = 'black', capsize=7, label='MLPRegressor')
plt.bar(r2, dtr, width = barWidth, color = 'saddlebrown', edgecolor = 'black',  capsize=7, label='DecisionTreeRegressor')
plt.bar(r3, sdg, width = barWidth, color = 'darkolivegreen', edgecolor = 'black',  capsize=7, label="SGDRegressor")
plt.bar(r4, br, width = barWidth, color = 'darkslategray', edgecolor = 'black',  capsize=7, label="BayesianRidge")

# general layout
plt.xticks([r + barWidth for r in range(len(mlp))], ['Binary Encoding', 'One-hot Encoding'])
plt.ylabel('R2 Score')
plt.legend()
plt.grid() 
# Show graphic
plt.show()

# %%
# Encoding regressor DD
import numpy as np
import matplotlib.pyplot as plt
 
# width of the bars
barWidth = 0.1
 
# Choose the height of the blue bars

 
# Choose the height of the cyan bars

 
# Choose the height of the error bars (bars1)
yer1 = [0.5, 0.4]
 
mlp = [0.74,0.8]
dtr=[0.61,0.81]
sdg=[0,0.8]
br=[0,0.79]
# Choose the height of the cyan bars


 
# The x position of bars
r1 = np.arange(len(mlp))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
# Create blue bars
plt.bar(r1, mlp, width = barWidth, color = 'goldenrod', edgecolor = 'black', capsize=7, label='MLPRegressor')
plt.bar(r2, dtr, width = barWidth, color = 'saddlebrown', edgecolor = 'black',  capsize=7, label='DecisionTreeRegressor')
plt.bar(r3, sdg, width = barWidth, color = 'darkolivegreen', edgecolor = 'black',  capsize=7, label="SGDRegressor")
plt.bar(r4, br, width = barWidth, color = 'darkslategray', edgecolor = 'black',  capsize=7, label="BayesianRidge")

# general layout
plt.xticks([r + barWidth for r in range(len(mlp))], ['Binary Encoding', 'One-hot Encoding'])
plt.ylabel('R2 Score')
plt.legend()
plt.grid() 
# Show graphic
plt.show()

# %%
# Encoding regressor proteins
import numpy as np
import matplotlib.pyplot as plt
 
# width of the bars
barWidth = 0.075
 
# Choose the height of the blue bars
mlp = [0.66,0.67]

dtr = [0.65,0.66]
 
sdg=[0.42,0.65]
br=[0.49,0.59]
# Choose the height of the cyan bars


 
# The x position of bars
r1 = np.arange(len(mlp))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
# Create blue bars
plt.bar(r1, mlp, width = barWidth, color = 'goldenrod', edgecolor = 'black', capsize=7, label='MLPRegressor')
plt.bar(r2, dtr, width = barWidth, color = 'saddlebrown', edgecolor = 'black',  capsize=7, label='DecisionTreeRegressor')
plt.bar(r3, sdg, width = barWidth, color = 'darkolivegreen', edgecolor = 'black',  capsize=7, label="SGDRegressor")
plt.bar(r4, br, width = barWidth, color = 'darkslategray', edgecolor = 'black',  capsize=7, label="BayesianRidge")

# general layout
plt.xticks([r + barWidth for r in range(len(mlp))], ['Binary Encoding', 'One-hot Encoding'])
plt.ylabel('R2 Score')
plt.legend()
plt.grid() 
# Show graphic
plt.show()

# %%
# Encoding regressor imdb
import numpy as np
import matplotlib.pyplot as plt
 
# width of the bars
barWidth = 0.075
 
# Choose the height of the blue bars
mlp = [0.81,0.84]

dtr = [0.81,0.83]
 
sdg=[0.78,0.79]
br=[0.77,0.77]
# Choose the height of the cyan bars


 
# The x position of bars
r1 = np.arange(len(mlp))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
# Create blue bars
plt.bar(r1, mlp, width = barWidth, color = 'goldenrod', edgecolor = 'black', capsize=7, label='MLPRegressor')
plt.bar(r2, dtr, width = barWidth, color = 'saddlebrown', edgecolor = 'black',  capsize=7, label='DecisionTreeRegressor')
plt.bar(r3, sdg, width = barWidth, color = 'darkolivegreen', edgecolor = 'black',  capsize=7, label="SGDRegressor")
plt.bar(r4, br, width = barWidth, color = 'darkslategray', edgecolor = 'black',  capsize=7, label="BayesianRidge")

# general layout
plt.xticks([r + barWidth for r in range(len(mlp))], ['Binary Encoding', 'One-hot Encoding'])
plt.ylabel('R2 Score')
plt.legend()
plt.grid() 
# Show graphic
plt.show()

# %%
import torch_geometric.datasets as dt
a= dt.DG
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8776\1739575477.py in <module>
#       1 import torch_geometric.datasets as dt
# ----> 2 a= dt.DGraphFin (root="ok")
#
# AttributeError: module 'torch_geometric.datasets' has no attribute 'DGraphFin'
